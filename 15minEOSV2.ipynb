# %%
from vnpy.trader.vtConstant import *
from vnpy.trader.app.ctaStrategy import CtaTemplate
import talib as ta
import numpy as np

########################################################################
# 策略继承CtaTemplate
class MultiFrameMaStrategy(CtaTemplate):
    className = 'MultiFrameMaStrategy'
    author = 'ChannelCMT'
    
    # 策略参数
    RSIPeriodfast = 6; RSIPeriodslow = 12
    Cortime = 6
    stopRatio = 0.03
    lot = 10000
    stdparam = 24
    fastmaperiod = 5
    slowmaperiod = 60
    
    # 策略变量
    maTrend = {} # 记录趋势状态，多头1，空头-1
    transactionPrice = {} # 记录成交价格
    DelVol = {} #记录量是否增长
    
    # 参数列表，保存了参数的名称
    paramList = [
                 'RSIPeriodfast',
                 'RSIPeriodslow',
                 'Cortime',
                 'stopRatio',
                 'stdparam'
                ]    
    
    # 变量列表，保存了变量的名称
    varList = [
               'stdparam',
               'transactionPrice'
              ]  
    
    # 同步列表，保存了需要保存到数据库的变量名称
    syncList = ['posDict', 'eveningDict']

    #----------------------------------------------------------------------
    def __init__(self, ctaEngine, setting):
        super().__init__(ctaEngine, setting)
    
    #----------------------------------------------------------------------
    def onInit(self):
        """初始化策略"""
        self.writeCtaLog(u'策略初始化')
        self.transactionPrice = {s:0 for s in self.symbolList} # 生成成交价格的字典
        self.maTrend = {s:0 for s in self.symbolList}
        self.putEvent()

    #----------------------------------------------------------------------
    def onStart(self):
        """启动策略"""
        self.writeCtaLog(u'策略启动')
        self.putEvent()
    
    #----------------------------------------------------------------------
    def onStop(self):
        """停止策略"""
        self.writeCtaLog(u'策略停止')
        self.putEvent()
        
    #----------------------------------------------------------------------
    def onTick(self, tick):
        """收到行情TICK推送"""
        pass
    
    #----------------------------------------------------------------------
    def onBar(self, bar):
        """收到Bar推送"""
        self.onBarStopLoss(bar)

    def onBarStopLoss(self, bar):
        symbol = bar.vtSymbol
        
        # 计算止损止盈价位
        longStop = self.transactionPrice[symbol]*(1-self.stopRatio)
        longProfit = self.transactionPrice[symbol]*(1+4*self.stopRatio)
        shortStop = self.transactionPrice[symbol]*(1+self.stopRatio)
        shortProfit = self.transactionPrice[symbol]*(1-4*self.stopRatio)
        
        
        # 洗价器
        if (self.posDict[symbol+'_LONG'] > 0):
            if (bar.close < longStop):
                print('LONG stopLoss')
                self.cancelAll()
                self.sell(symbol,bar.close*0.99, self.lot)
            elif  (bar.close > longProfit):
                print('LONG takeProfit')
                self.cancelAll()
                self.sell(symbol,bar.close*0.99, self.lot)

        elif (self.posDict[symbol+'_SHORT'] > 0):
            if (bar.close > shortStop):
                print('SHORT stopLoss')
                self.cancelAll()
                self.cover(symbol,bar.close*1.01, self.lot)
            elif (bar.close < shortProfit):
                print('SHORT takeProfit')
                self.cancelAll()
                self.cover(symbol,bar.close*1.01, self.lot)

    #----------------------------------------------------------------------
    def on15MinBar(self, bar):
        """收到60MinBar推送"""
        symbol = bar.vtSymbol
        
        am15 = self.getArrayManager(symbol, "15m")
        
        if not am15.inited:
            return
        Mafast = ta.MA(am15.close,self.fastmaperiod)
        Maslow = ta.MA(am15.close,self.slowmaperiod)
        diff = Mafast - Maslow
        bol = np.abs(diff)>0.1
        angle = ta.LINEARREG_ANGLE(Maslow,5)
        i = 1
        if(bol[-i]==False):
            sum1 = 0
            sum2 = 0
            sum3 = 0
            while(bol[-i]==False and i<len(diff)):
                i = i+1
            while(bol[-i]==True and i<len(diff)):
                sum1 = sum1+diff[-i]
                i = i+1
            while(bol[-i]==False and i<len(diff)):
                i = i+1
            while(bol[-i]==True and i<len(diff)):
                sum2 = sum2+diff[-i]
                i = i+1
            while(bol[-i]==False and i<len(diff)):
                i = i+1
            while(bol[-i]==True and i<len(diff)):
                sum3 = sum3+diff[-i]
                i = i+1
            if angle[-1]>-30 and (((sum1<0) and (sum1>sum2))or(np.abs(sum2)<min(np.abs(sum1),np.abs(sum3)) and sum1<0 and sum1>sum3)):
            # 做多信号
                if  (self.posDict[symbol+'_SHORT']==0)and(self.posDict[symbol+'_LONG']==0):
                    self.buy(symbol, bar.close*1.01, self.lot)  # 成交价*1.01发送高价位的限价单，以最优市价买入进场
            # 如果有空头持仓，则先平空，再做多
                elif self.posDict[symbol+'_SHORT'] > 0:
                    self.cancelAll() # 撤销挂单
                    self.cover(symbol, bar.close*1.01, self.posDict[symbol+'_SHORT']) 
                    self.buy(symbol, bar.close*1.01, self.lot)
        # 做空信号
            elif angle[-1]<30 and (((sum1>0) and (sum2>sum1)) or (np.abs(sum2)<min(sum1,sum3) and sum1>0 and sum1<sum3)):
                if (self.posDict[symbol+'_LONG']==0)and(self.posDict[symbol+'_SHORT']==0):
                    self.short(symbol, bar.close*0.99, self.lot) # 成交价*0.99发送低价位的限价单，以最优市价卖出进场
                elif self.posDict[symbol+'_LONG'] > 0:
                    self.cancelAll() # 撤销挂单
                    self.sell(symbol, bar.close*0.99, self.posDict[symbol+'_LONG'])
                    self.short(symbol, bar.close*0.99, self.lot)
        self.putEvent()
    #----------------------------------------------------------------------
    def on60MinBar(self, bar):
        """收到60MinBar推送"""
        symbol = bar.vtSymbol
        
        am60 = self.getArrayManager(symbol, "60m")
        
        if not am60.inited:
            return
        
        alpha2 = -1*ta.CORREL(np.diff(ta.LOG10(ta.MA(am60.volume,24)),1),np.diff(ta.LOG10(ta.MA((am60.high-am60.low)/(am60.close),24)),1),self.Cortime)
        alpha2mean = ta.MA(alpha2,5)
        STD = ta.STDDEV(np.diff(am60.close)/am60.close[:-1], self.stdparam)
        RSIfast = ta.RSI(am60.close,self.RSIPeriodfast)
        RSIslow = ta.RSI(am60.close,self.RSIPeriodslow)
        
        fastMa = ta.EMA(am60.close, self.fastmaperiod)
        slowMa = ta.EMA(am60.close, self.slowmaperiod)
        angle60 = ta.LINEARREG_ANGLE(slowMa,timeperiod=4)
        if (angle60[-1]>0) and(RSIfast[-1]>RSIslow[-1]) and  (alpha2mean[-1]>-0.3) and (STD[-1]<0.008) and (self.posDict[symbol+'_LONG']==0):
            if  (self.posDict[symbol+'_SHORT']==0):
                self.buy(symbol, bar.close*1.01, self.lot)  # 成交价*1.01发送高价位的限价单，以最优市价买入进场
            elif (self.posDict[symbol+'_SHORT'] > 0):
                self.cancelAll() # 撤销挂单
                self.cover(symbol, bar.close*1.01, self.posDict[symbol+'_SHORT']) 
                self.buy(symbol, bar.close*1.01, self.lot)
        if (angle60[-1]<0) and (RSIfast[-1]<RSIslow[-1]) and (alpha2mean[-1]>-0.3) and (STD[-1]<0.008) and (self.posDict[symbol+'_SHORT']==0):
            if (self.posDict[symbol+'_LONG']==0):
                self.short(symbol, bar.close*0.99, self.lot) # 成交价*0.99发送低价位的限价单，以最优市价卖出进场
            elif (self.posDict[symbol+'_LONG'] > 0):
                self.cancelAll() # 撤销挂单
                self.sell(symbol, bar.close*0.99, self.posDict[symbol+'_LONG'])
                self.short(symbol, bar.close*0.99, self.lot)
        self.putEvent()
    
    
    #----------------------------------------------------------------------
    def onOrder(self, order):
        """收到委托变化推送（必须由用户继承实现）"""
        # 对于无需做细粒度委托控制的策略，可以忽略onOrder
        pass
    
    #----------------------------------------------------------------------
    def onTrade(self, trade):
        """收到成交推送（必须由用户继承实现）"""
        symbol = trade.vtSymbol
        if trade.offset == OFFSET_OPEN:  # 判断成交订单类型
            self.transactionPrice[symbol] = trade.price # 记录成交价格
            print(trade.tradeTime, self.posDict)
    #----------------------------------------------------------------------
    def onStopOrder(self, so):
        """停止单推送"""
        pass

# %%
from vnpy.trader.app.ctaStrategy import BacktestingEngine
import pandas as pd

def runBacktesting(strategyClass, settingDict,
                   startDate, endDate, slippage, rate):
    engine = BacktestingEngine()
    engine.setBacktestingMode(engine.BAR_MODE)  # 设置引擎的回测模式为K线
    engine.setDatabase('VnTrader_1Min_Db')    # 设置使用的历史数据库
    engine.setStartDate(startDate, initHours=200)   # 设置回测用的数据起始日期
    engine.setEndDate(endDate)     # 设置回测用的数据结束日期
    engine.setSlippage(slippage)    # 设置滑点
    engine.setRate(rate)             # 设置手续费万0.3
    engine.initStrategy(strategyClass, settingDict)
    engine.setCapital(100000)     # 设置回测本金
    engine.runBacktesting()
    #显示逐日回测结果
    engine.showDailyResult()
    #显示逐笔回测结果
    engine.showBacktestingResult()
    # 计算回测结果
    perfromance = engine.calculateDailyResult()
    perfromanceDf , result = engine.calculateDailyStatistics(perfromance)
    tradeReport = pd.DataFrame([obj.__dict__ for obj in engine.tradeDict.values()])
    tradeDf = tradeReport.set_index('dt')
    return perfromanceDf, tradeDf

# %%
parameterDict = {'symbolList':['EOSUSDT:binance']}
runBacktesting(MultiFrameMaStrategy, parameterDict, '20180701 12:00', '20181121 12:00', 0.002, 5/10000)
# Out:
# 仓位字典构造完成
# 初始仓位: {'EOSUSDT:binance_LONG': 0, 'EOSUSDT:binance_SHORT': 0}
# [DEBUG] 注册品种EOSUSDT:binance上的on_60Min_bar函数functools.partial(<function MultiFrameMaStrategy.on60MinBar at 0x130819488>, <__main__.MultiFrameMaStrategy object at 0x12d86f588>)
# [DEBUG] 注册品种EOSUSDT:binance上的on_15Min_bar函数functools.partial(<function MultiFrameMaStrategy.on15MinBar at 0x130823a60>, <__main__.MultiFrameMaStrategy object at 0x12d86f588>)
# [DEBUG] 注册品种EOSUSDT:binance上的on_1m_bar函数functools.partial(<function MultiFrameMaStrategy.onBar at 0x130804e18>, <__main__.MultiFrameMaStrategy object at 0x12d86f588>)
# 2018-12-11 20:16:27.336846	开始回测
# 2018-12-11 20:16:27.336926	策略初始化
# 2018-12-11 20:16:27.339145	载入历史数据。数据范围:[20180623 04:00,20180701 12:00)
# 2018-12-11 20:16:27.840370	 当前品种 EOSUSDT:binance 的数据，全部来自于本地缓存
# 2018-12-11 20:16:27.843123	载入完成，数据量：11295
# 2018-12-11 20:16:27.843556	策略初始化完成
# 2018-12-11 20:16:27.843604	策略启动完成
# 2018-12-11 20:16:27.843695	开始回放回测数据,回测范围:[20180701 12:00,20181121 12:00)
# 2018-12-11 20:16:27.866025	载入历史数据。数据范围:[20180701 12:00,20181121 12:00)
# 2018-12-11 20:16:37.717834	 当前品种 EOSUSDT:binance 的数据，全部来自于本地缓存
# 2018-12-11 20:16:37.781077	载入完成，数据量：204833
# 2018-12-11 20:16:37.781509	当前回放数据:[20180701 12:00,20181121 12:00)
# [INFO] 品种EOSUSDT:binance开始生成未完成的1mK线数据,时间起点为:20180701120000
# 2018-12-11 20:16:37.784602	载入历史数据。数据范围:[20180630 20:51,20180703 12:01)
# 2018-12-11 20:16:38.052734	 当前品种 EOSUSDT:binance 的数据，全部来自于本地缓存
# 2018-12-11 20:16:38.056037	载入完成，数据量：3790
# [INFO] 品种EOSUSDT:binance的历史1mK线更新，范围为:[20180701102100 , 20180701120000]
# [INFO] 品种EOSUSDT:binance的1mK线准备就绪,当前K线时间为20180701120000
# [INFO] 品种EOSUSDT:binance开始生成未完成的60mK线数据,时间起点为:20180701120000
# 2018-12-11 20:16:38.096656	载入历史数据。数据范围:[20180524 15:00,20180630 20:50)
# 2018-12-11 20:16:40.534774	失去MongoDB的连接，我们尝试使用本地缓存数据，请注意数据量
# 2018-12-11 20:16:40.550515	载入完成，数据量：47285
# 2018-12-11 20:16:40.555513	载入历史数据。数据范围:[20180703 12:01,20180703 13:00)
# 2018-12-11 20:16:40.560281	 当前品种 EOSUSDT:binance 的数据，全部来自于本地缓存
# 2018-12-11 20:16:40.560358	！！ 数据量为 0 ！！
# Traceback (most recent call last):
#   File "/Users/yuewang/anaconda3/lib/python3.6/site-packages/vnpy_fxdayu-1.1.14-py3.6.egg/vnpy/trader/app/ctaStrategy/ctaBacktesting.py", line 282, in loadHistoryData
#     dataList += [self.parseData(dataClass, item) for item in data_df[(data_df.datetime>=start) & (data_df.datetime<end)].to_dict("record")]
#   File "/Users/yuewang/anaconda3/lib/python3.6/site-packages/pandas/core/generic.py", line 3081, in __getattr__
#     return object.__getattribute__(self, name)
# AttributeError: 'DataFrame' object has no attribute 'datetime'
# [INFO] 品种EOSUSDT:binance的历史60mK线更新，范围为:[20180627070000 , 20180701110000]
# [INFO] 品种EOSUSDT:binance开始生成未完成的15mK线数据,时间起点为:20180701120000
# [INFO] 品种EOSUSDT:binance的历史15mK线更新，范围为:[20180630110000 , 20180701114500]
# [INFO] 品种EOSUSDT:binance开始生成1mK线数据,时间起点为:20180701120100
# [INFO] 品种EOSUSDT:binance开始生成60mK线数据,时间起点为:20180701120000
# [INFO] 品种EOSUSDT:binance开始生成15mK线数据,时间起点为:20180701120000
# [DEBUG] merged bar {'gatewayName': '', 'rawData': None, 'vtSymbol': 'EOSUSDT:binance', 'symbol': 'EOSUSDT', 'exchange': 'binance', 'open': 7.9618, 'high': 7.9785, 'low': 7.9555, 'close': 7.9666, 'date': '20180701', 'time': '12:00:00.000000', 'datetime': datetime.datetime(2018, 7, 1, 12, 0), 'volume': 76756.84999999999, 'openInterest': 0}
# /Users/yuewang/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:121: RuntimeWarning: invalid value encountered in greater
# [INFO] 品种EOSUSDT:binance的历史15mK线更新，范围为:[20180630111500 , 20180701120000]
# [INFO] 品种EOSUSDT:binance的15mK线准备就绪,当前K线时间为20180701120000
# [DEBUG] merged bar {'gatewayName': '', 'rawData': None, 'vtSymbol': 'EOSUSDT:binance', 'symbol': 'EOSUSDT', 'exchange': 'binance', 'open': 7.9618, 'high': 8.0198, 'low': 7.9359, 'close': 8.0136, 'date': '20180701', 'time': '12:00:00.000000', 'datetime': datetime.datetime(2018, 7, 1, 12, 0), 'volume': 354895.4799999999, 'openInterest': 0}
# [INFO] 品种EOSUSDT:binance的历史60mK线更新，范围为:[20180627080000 , 20180701120000]
# [INFO] 品种EOSUSDT:binance的60mK线准备就绪,当前K线时间为20180701120000
# 2018-07-02 06:00:00 {'EOSUSDT:binance_LONG': 10000, 'EOSUSDT:binance_SHORT': 0}
# LONG takeProfit6:45.877903	Progress: 1%
# 2018-07-04 03:15:00 {'EOSUSDT:binance_LONG': 10000, 'EOSUSDT:binance_SHORT': 0}
# LONG stopLoss:16:46.238678	Progress: 3%
# 2018-07-09 17:00:00 {'EOSUSDT:binance_LONG': 0, 'EOSUSDT:binance_SHORT': 10000}
# SHORT takeProfit
# 2018-07-11 08:45:00.886633	Progress: 6%     {'EOSUSDT:binance_LONG': 10000, 'EOSUSDT:binance_SHORT': 0}
# LONG stopLoss
# 2018-07-14 18:00:00 {'EOSUSDT:binance_LONG': 0, 'EOSUSDT:binance_SHORT': 10000}
# SHORT stopLoss
# 2018-07-15 02:00:00 {'EOSUSDT:binance_LONG': 10000, 'EOSUSDT:binance_SHORT': 0}
# 2018-07-15 02:15:00 {'EOSUSDT:binance_LONG': 0, 'EOSUSDT:binance_SHORT': 10000}
# 2018-07-15 06:00:00 {'EOSUSDT:binance_LONG': 10000, 'EOSUSDT:binance_SHORT': 0}
# 2018-07-15 06:15:00 {'EOSUSDT:binance_LONG': 0, 'EOSUSDT:binance_SHORT': 10000}
# 2018-07-15 14:00:00 {'EOSUSDT:binance_LONG': 10000, 'EOSUSDT:binance_SHORT': 0}
# LONG takeProfit6:47.636468	Progress: 10%
# 2018-07-19 15:45:00 {'EOSUSDT:binance_LONG': 10000, 'EOSUSDT:binance_SHORT': 0}
# LONG stopLoss
# 2018-07-23 00:00:00 {'EOSUSDT:binance_LONG': 10000, 'EOSUSDT:binance_SHORT': 0}
# 2018-07-23 02:00:00 {'EOSUSDT:binance_LONG': 0, 'EOSUSDT:binance_SHORT': 10000}
# SHORT stopLoss16:48.540954	Progress: 15%
# 2018-07-24 09:45:00 {'EOSUSDT:binance_LONG': 10000, 'EOSUSDT:binance_SHORT': 0}
# LONG takeProfit6:48.720860	Progress: 16%
# 2018-07-27 22:15:00 {'EOSUSDT:binance_LONG': 10000, 'EOSUSDT:binance_SHORT': 0}
# 2018-07-29 13:00:00.255750	Progress: 19%     {'EOSUSDT:binance_LONG': 0, 'EOSUSDT:binance_SHORT': 10000}
# SHORT takeProfit:49.616260	Progress: 21%
# 2018-08-01 04:00:00 {'EOSUSDT:binance_LONG': 10000, 'EOSUSDT:binance_SHORT': 0}
# LONG stopLoss
# 2018-08-03 13:00:00 {'EOSUSDT:binance_LONG': 10000, 'EOSUSDT:binance_SHORT': 0}
# 2018-08-04 11:15:00 {'EOSUSDT:binance_LONG': 0, 'EOSUSDT:binance_SHORT': 10000}
# 2018-08-04 12:00:00 {'EOSUSDT:binance_LONG': 10000, 'EOSUSDT:binance_SHORT': 0}
# 2018-08-04 12:15:00 {'EOSUSDT:binance_LONG': 0, 'EOSUSDT:binance_SHORT': 10000}
# 2018-08-05 05:45:00 {'EOSUSDT:binance_LONG': 10000, 'EOSUSDT:binance_SHORT': 0}
# 2018-08-05 09:00:00 {'EOSUSDT:binance_LONG': 0, 'EOSUSDT:binance_SHORT': 10000}
# 2018-08-05 09:15:00 {'EOSUSDT:binance_LONG': 10000, 'EOSUSDT:binance_SHORT': 0}
# 2018-08-05 16:00:00 {'EOSUSDT:binance_LONG': 0, 'EOSUSDT:binance_SHORT': 10000}
# 2018-08-06 06:00:00 {'EOSUSDT:binance_LONG': 10000, 'EOSUSDT:binance_SHORT': 0}
# 2018-08-06 17:00:00 {'EOSUSDT:binance_LONG': 0, 'EOSUSDT:binance_SHORT': 10000}
# 2018-08-07 09:00:00 {'EOSUSDT:binance_LONG': 10000, 'EOSUSDT:binance_SHORT': 0}
# LONG stopLoss:16:50.580890	Progress: 26%
# 2018-08-10 23:30:00 {'EOSUSDT:binance_LONG': 10000, 'EOSUSDT:binance_SHORT': 0}
# LONG stopLoss
# 2018-08-11 23:15:00 {'EOSUSDT:binance_LONG': 10000, 'EOSUSDT:binance_SHORT': 0}
# 2018-08-12 07:30:00 {'EOSUSDT:binance_LONG': 0, 'EOSUSDT:binance_SHORT': 10000}
# SHORT takeProfit:51.302548	Progress: 30%
# 2018-08-17 22:00:00 {'EOSUSDT:binance_LONG': 0, 'EOSUSDT:binance_SHORT': 10000}
# SHORT stopLoss
# 2018-08-20 06:15:00 {'EOSUSDT:binance_LONG': 0, 'EOSUSDT:binance_SHORT': 10000}
# 2018-08-20 23:45:00 {'EOSUSDT:binance_LONG': 10000, 'EOSUSDT:binance_SHORT': 0}
# LONG stopLoss
# 2018-08-25 23:00:00 {'EOSUSDT:binance_LONG': 10000, 'EOSUSDT:binance_SHORT': 0}
# LONG stopLoss:16:53.035287	Progress: 39%
# 2018-08-26 21:00:00 {'EOSUSDT:binance_LONG': 10000, 'EOSUSDT:binance_SHORT': 0}
# 2018-08-27 01:00:00 {'EOSUSDT:binance_LONG': 0, 'EOSUSDT:binance_SHORT': 10000}
# 2018-08-27 03:00:00 {'EOSUSDT:binance_LONG': 10000, 'EOSUSDT:binance_SHORT': 0}
# LONG takeProfit6:53.250981	Progress: 40%
# 2018-08-30 06:30:00 {'EOSUSDT:binance_LONG': 0, 'EOSUSDT:binance_SHORT': 10000}
# SHORT stopLoss16:53.764279	Progress: 43%
# 2018-09-01 16:45:00 {'EOSUSDT:binance_LONG': 0, 'EOSUSDT:binance_SHORT': 10000}
# 2018-09-04 20:00:00 {'EOSUSDT:binance_LONG': 10000, 'EOSUSDT:binance_SHORT': 0}
# LONG stopLoss:16:54.438603	Progress: 46%
# 2018-09-11 16:00:00 {'EOSUSDT:binance_LONG': 0, 'EOSUSDT:binance_SHORT': 10000}
# SHORT stopLoss16:55.620077	Progress: 52%
# 2018-09-14 11:45:00 {'EOSUSDT:binance_LONG': 0, 'EOSUSDT:binance_SHORT': 10000}
# 2018-09-16 18:00:00 {'EOSUSDT:binance_LONG': 10000, 'EOSUSDT:binance_SHORT': 0}
# 2018-09-17 17:00:00 {'EOSUSDT:binance_LONG': 0, 'EOSUSDT:binance_SHORT': 10000}
# SHORT takeProfit:56.159526	Progress: 55%
# 2018-09-21 21:15:00 {'EOSUSDT:binance_LONG': 0, 'EOSUSDT:binance_SHORT': 10000}
# SHORT stopLoss
# 2018-09-23 00:00:00 {'EOSUSDT:binance_LONG': 10000, 'EOSUSDT:binance_SHORT': 0}
# LONG stopLoss:16:56.878913	Progress: 59%
# 2018-09-28 17:00:00 {'EOSUSDT:binance_LONG': 0, 'EOSUSDT:binance_SHORT': 10000}
# 2018-10-04 10:00:00 {'EOSUSDT:binance_LONG': 10000, 'EOSUSDT:binance_SHORT': 0}
# 2018-10-07 17:00:00 {'EOSUSDT:binance_LONG': 0, 'EOSUSDT:binance_SHORT': 10000}
# 2018-10-08 07:00:00 {'EOSUSDT:binance_LONG': 10000, 'EOSUSDT:binance_SHORT': 0}
# LONG stopLoss:16:59.323357	Progress: 71%
# 2018-10-14 18:00:00 {'EOSUSDT:binance_LONG': 0, 'EOSUSDT:binance_SHORT': 10000}
# SHORT stopLoss16:59.938477	Progress: 74%
# 2018-10-17 03:00:00 {'EOSUSDT:binance_LONG': 10000, 'EOSUSDT:binance_SHORT': 0}
# 2018-10-19 01:00:00 {'EOSUSDT:binance_LONG': 0, 'EOSUSDT:binance_SHORT': 10000}
# 2018-10-21 10:00:00 {'EOSUSDT:binance_LONG': 10000, 'EOSUSDT:binance_SHORT': 0}
# 2018-10-22 08:00:00 {'EOSUSDT:binance_LONG': 0, 'EOSUSDT:binance_SHORT': 10000}
# 2018-10-29 00:00:00 {'EOSUSDT:binance_LONG': 10000, 'EOSUSDT:binance_SHORT': 0}
# 2018-10-29 03:00:00 {'EOSUSDT:binance_LONG': 0, 'EOSUSDT:binance_SHORT': 10000}
# SHORT stopLoss17:02.617321	Progress: 88%
# 2018-11-07 00:00:00 {'EOSUSDT:binance_LONG': 0, 'EOSUSDT:binance_SHORT': 10000}
# SHORT takeProfit:04.094826	Progress: 95%
# 2018-11-15 14:00:00 {'EOSUSDT:binance_LONG': 10000, 'EOSUSDT:binance_SHORT': 0}
# LONG stopLoss
# 2018-11-16 00:15:00 {'EOSUSDT:binance_LONG': 10000, 'EOSUSDT:binance_SHORT': 0}
# LONG stopLoss
# 2018-11-18 18:00:00 {'EOSUSDT:binance_LONG': 0, 'EOSUSDT:binance_SHORT': 10000}
# SHORT takeProfit
# 2018-12-11 20:17:05.106946	数据回放结束ss: 100%
# 2018-12-11 20:17:05.107079	计算按日统计结果
# 2018-12-11 20:17:05.147986	------------------------------
# 2018-12-11 20:17:05.148127	首个交易日：	2018-07-01 00:00:00
# 2018-12-11 20:17:05.148183	最后交易日：	2018-11-21 00:00:00
# 2018-12-11 20:17:05.148231	总交易日：	144
# 2018-12-11 20:17:05.148278	盈利交易日	55
# 2018-12-11 20:17:05.148326	亏损交易日：	54
# 2018-12-11 20:17:05.148374	起始资金：	100000
# 2018-12-11 20:17:05.148656	结束资金：	139,700.71
# 2018-12-11 20:17:05.148758	总收益率：	39.7%
# 2018-12-11 20:17:05.148870	年化收益：	66.17%
# 2018-12-11 20:17:05.149033	总盈亏：	39,700.71
# 2018-12-11 20:17:05.149130	最大回撤: 	-10,449.43
# 2018-12-11 20:17:05.149310	百分比最大回撤: -7.43%
# 2018-12-11 20:17:05.149487	总手续费：	3,911.29
# 2018-12-11 20:17:05.149545	总滑点：	2,480.0
# 2018-12-11 20:17:05.149598	总成交金额：	7,822,578.0
# 2018-12-11 20:17:05.149748	总成交笔数：	124
# 2018-12-11 20:17:05.149801	日均盈亏：	275.7
# 2018-12-11 20:17:05.149854	日均手续费：	27.16
# 2018-12-11 20:17:05.149999	日均滑点：	17.22
# 2018-12-11 20:17:05.150054	日均成交金额：	54,323.46
# 2018-12-11 20:17:05.150106	日均成交笔数：	0.86
# 2018-12-11 20:17:05.150171	日均收益率：	0.23%
# 2018-12-11 20:17:05.150328	收益标准差：	1.72%
# 2018-12-11 20:17:05.150409	Sharpe Ratio：	2.1
# 2018-12-11 20:17:07.990990	计算回测结果
# 2018-12-11 20:17:08.003858	------------------------------
# 2018-12-11 20:17:08.003993	第一笔交易：	2018-07-03 03:18:00
# 2018-12-11 20:17:08.004066	最后一笔交易：	2018-11-19 17:55:00
# 2018-12-11 20:17:08.004133	总交易次数：	62
# 2018-12-11 20:17:08.004298	总盈亏：	39,700.71
# 2018-12-11 20:17:08.004371	最大回撤: 	-9,235.68
# 2018-12-11 20:17:08.004541	平均每笔盈利：	640.33
# 2018-12-11 20:17:08.004606	平均每笔滑点：	40.0
# 2018-12-11 20:17:08.004807	平均每笔佣金：	63.09
# 2018-12-11 20:17:08.004873	胜率		32.26%
# 2018-12-11 20:17:08.005018	盈利交易平均值	4,638.81
# 2018-12-11 20:17:08.005085	亏损交易平均值	-1,263.7
# 2018-12-11 20:17:08.005249	盈亏比：	3.67
# 2018-12-11 20:17:09.243180	计算按日统计结果
# (                netPnl  slippage  commission  turnover  tradeCount  \
#  date
#  2018-07-01      0.0000       0.0      0.0000       0.0           0
#  2018-07-02   7988.3905      20.0     40.6095   81219.0           1
#  2018-07-03   1840.4130      20.0     45.5870   91174.0           1
#  2018-07-04   2195.4575      20.0     44.5425   89085.0           1
#  2018-07-05  -1807.0000       0.0      0.0000       0.0           0
#  2018-07-06  -3130.2355      20.0     43.2355   86471.0           1
#  2018-07-07      0.0000       0.0      0.0000       0.0           0
#  2018-07-08      0.0000       0.0      0.0000       0.0           0
#  2018-07-09   -296.9085      20.0     42.9085   85817.0           1
#  2018-07-10  10803.4050      20.0     37.5950   75190.0           1
#  2018-07-11  -2354.1920      40.0     72.1920  144384.0           2
#  2018-07-12      0.0000       0.0      0.0000       0.0           0
#  2018-07-13      0.0000       0.0      0.0000       0.0           0
#  2018-07-14  -1012.2140      20.0     34.2140   68428.0           1
#  2018-07-15   2203.3220     200.0    349.6780  699356.0          10
#  2018-07-16   3994.8095      20.0     39.1905   78381.0           1
#  2018-07-17      0.0000       0.0      0.0000       0.0           0
#  2018-07-18      0.0000       0.0      0.0000       0.0           0
#  2018-07-19  -1064.3645      20.0     42.3645   84729.0           1
#  2018-07-20  -1661.0635      20.0     41.0635   82127.0           1
#  2018-07-21      0.0000       0.0      0.0000       0.0           0
#  2018-07-22      0.0000       0.0      0.0000       0.0           0
#  2018-07-23  -3864.0065      80.0    163.0065  326013.0           4
#  2018-07-24   5544.5715      20.0     39.4285   78857.0           1
#  2018-07-25   4155.6595      20.0     44.3405   88681.0           1
#  2018-07-26      0.0000       0.0      0.0000       0.0           0
#  2018-07-27   2472.4330      20.0     40.5670   81134.0           1
#  2018-07-28  -1154.0000       0.0      0.0000       0.0           0
#  2018-07-29   -172.7490      40.0     82.7490  165498.0           2
#  2018-07-30   3971.0000       0.0      0.0000       0.0           0
#  ...                ...       ...         ...       ...         ...
#  2018-10-23    386.0000       0.0      0.0000       0.0           0
#  2018-10-24   -265.0000       0.0      0.0000       0.0           0
#  2018-10-25    287.0000       0.0      0.0000       0.0           0
#  2018-10-26     37.0000       0.0      0.0000       0.0           0
#  2018-10-27    131.0000       0.0      0.0000       0.0           0
#  2018-10-28    -94.0000       0.0      0.0000       0.0           0
#  2018-10-29   2323.4340      80.0    108.5660  217132.0           4
#  2018-10-30    237.0000       0.0      0.0000       0.0           0
#  2018-10-31  -1253.0000       0.0      0.0000       0.0           0
#  2018-11-01    375.0000       0.0      0.0000       0.0           0
#  2018-11-02  -1528.0000       0.0      0.0000       0.0           0
#  2018-11-03    567.0000       0.0      0.0000       0.0           0
#  2018-11-04  -1620.0000       0.0      0.0000       0.0           0
#  2018-11-05  -1022.9980      20.0     27.9980   55996.0           1
#  2018-11-06      0.0000       0.0      0.0000       0.0           0
#  2018-11-07    540.4575      20.0     28.5425   57085.0           1
#  2018-11-08    704.0000       0.0      0.0000       0.0           0
#  2018-11-09   1638.0000       0.0      0.0000       0.0           0
#  2018-11-10   -128.0000       0.0      0.0000       0.0           0
#  2018-11-11   1231.0000       0.0      0.0000       0.0           0
#  2018-11-12  -1543.0000       0.0      0.0000       0.0           0
#  2018-11-13    111.0000       0.0      0.0000       0.0           0
#  2018-11-14   4546.0540      20.0     24.9460   49892.0           1
#  2018-11-15  -1576.8375      40.0     45.8375   91675.0           2
#  2018-11-16  -1495.8260      40.0     45.8260   91652.0           2
#  2018-11-17      0.0000       0.0      0.0000       0.0           0
#  2018-11-18    126.8285      20.0     23.1715   46343.0           1
#  2018-11-19   5301.5845      20.0     20.4155   40831.0           1
#  2018-11-20      0.0000       0.0      0.0000       0.0           0
#  2018-11-21      0.0000       0.0      0.0000       0.0           0
#
#              tradingPnl  positionPnl  totalPnl      balance    return  \
#  date
#  2018-07-01         0.0          0.0       0.0  100000.0000  0.000000
#  2018-07-02      8049.0          0.0    8049.0  107988.3905  0.076854
#  2018-07-03      1184.0        722.0    1906.0  109828.8035  0.016899
#  2018-07-04      2260.0          0.0    2260.0  112024.2610  0.019793
#  2018-07-05         0.0      -1807.0   -1807.0  110217.2610 -0.016262
#  2018-07-06       912.0      -3979.0   -3067.0  107087.0255 -0.028812
#  2018-07-07         0.0          0.0       0.0  107087.0255  0.000000
#  2018-07-08         0.0          0.0       0.0  107087.0255  0.000000
#  2018-07-09      -234.0          0.0    -234.0  106790.1170 -0.002776
#  2018-07-10     -2290.0      13151.0   10861.0  117593.5220  0.096369
#  2018-07-11     -2242.0          0.0   -2242.0  115239.3300 -0.020223
#  2018-07-12         0.0          0.0       0.0  115239.3300  0.000000
#  2018-07-13         0.0          0.0       0.0  115239.3300  0.000000
#  2018-07-14      -958.0          0.0    -958.0  114227.1160 -0.008822
#  2018-07-15      7694.0      -4941.0    2753.0  116430.4380  0.019105
#  2018-07-16     -1203.0       5257.0    4054.0  120425.2475  0.033735
#  2018-07-17         0.0          0.0       0.0  120425.2475  0.000000
#  2018-07-18         0.0          0.0       0.0  120425.2475  0.000000
#  2018-07-19     -1002.0          0.0   -1002.0  119360.8830 -0.008878
#  2018-07-20       829.0      -2429.0   -1600.0  117699.8195 -0.014014
#  2018-07-21         0.0          0.0       0.0  117699.8195  0.000000
#  2018-07-22         0.0          0.0       0.0  117699.8195  0.000000
#  2018-07-23     -3621.0          0.0   -3621.0  113835.8130 -0.033380
#  2018-07-24      5604.0          0.0    5604.0  119380.3845  0.047558
#  2018-07-25      4181.0         39.0    4220.0  123536.0440  0.034218
#  2018-07-26         0.0          0.0       0.0  123536.0440  0.000000
#  2018-07-27      2533.0          0.0    2533.0  126008.4770  0.019816
#  2018-07-28         0.0      -1154.0   -1154.0  124854.4770 -0.009200
#  2018-07-29      -572.0        522.0     -50.0  124681.7280 -0.001385
#  2018-07-30         0.0       3971.0    3971.0  128652.7280  0.031352
#  ...                ...          ...       ...          ...       ...
#  2018-10-23         0.0        386.0     386.0  132071.0140  0.002927
#  2018-10-24         0.0       -265.0    -265.0  131806.0140 -0.002009
#  2018-10-25         0.0        287.0     287.0  132093.0140  0.002175
#  2018-10-26         0.0         37.0      37.0  132130.0140  0.000280
#  2018-10-27         0.0        131.0     131.0  132261.0140  0.000991
#  2018-10-28         0.0        -94.0     -94.0  132167.0140 -0.000711
#  2018-10-29        -4.0       2516.0    2512.0  134490.4480  0.017427
#  2018-10-30         0.0        237.0     237.0  134727.4480  0.001761
#  2018-10-31         0.0      -1253.0   -1253.0  133474.4480 -0.009344
#  2018-11-01         0.0        375.0     375.0  133849.4480  0.002806
#  2018-11-02         0.0      -1528.0   -1528.0  132321.4480 -0.011481
#  2018-11-03         0.0        567.0     567.0  132888.4480  0.004276
#  2018-11-04         0.0      -1620.0   -1620.0  131268.4480 -0.012266
#  2018-11-05      -784.0       -191.0    -975.0  130245.4500 -0.007824
#  2018-11-06         0.0          0.0       0.0  130245.4500  0.000000
#  2018-11-07       589.0          0.0     589.0  130785.9075  0.004141
#  2018-11-08         0.0        704.0     704.0  131489.9075  0.005368
#  2018-11-09         0.0       1638.0    1638.0  133127.9075  0.012380
#  2018-11-10         0.0       -128.0    -128.0  132999.9075 -0.000962
#  2018-11-11         0.0       1231.0    1231.0  134230.9075  0.009213
#  2018-11-12         0.0      -1543.0   -1543.0  132687.9075 -0.011562
#  2018-11-13         0.0        111.0     111.0  132798.9075  0.000836
#  2018-11-14     -1119.0       5710.0    4591.0  137344.9615  0.033660
#  2018-11-15     -1491.0          0.0   -1491.0  135768.1240 -0.011547
#  2018-11-16     -1410.0          0.0   -1410.0  134272.2980 -0.011079
#  2018-11-17         0.0          0.0       0.0  134272.2980  0.000000
#  2018-11-18       170.0          0.0     170.0  134399.1265  0.000944
#  2018-11-19       539.0       4803.0    5342.0  139700.7110  0.038688
#  2018-11-20         0.0          0.0       0.0  139700.7110  0.000000
#  2018-11-21         0.0          0.0       0.0  139700.7110  0.000000
#
#                highlevel    drawdown  ddPercent
#  date
#  2018-07-01  100000.0000      0.0000   0.000000
#  2018-07-02  107988.3905      0.0000   0.000000
#  2018-07-03  109828.8035      0.0000   0.000000
#  2018-07-04  112024.2610      0.0000   0.000000
#  2018-07-05  112024.2610  -1807.0000  -1.613043
#  2018-07-06  112024.2610  -4937.2355  -4.407291
#  2018-07-07  112024.2610  -4937.2355  -4.407291
#  2018-07-08  112024.2610  -4937.2355  -4.407291
#  2018-07-09  112024.2610  -5234.1440  -4.672331
#  2018-07-10  117593.5220      0.0000   0.000000
#  2018-07-11  117593.5220  -2354.1920  -2.001974
#  2018-07-12  117593.5220  -2354.1920  -2.001974
#  2018-07-13  117593.5220  -2354.1920  -2.001974
#  2018-07-14  117593.5220  -3366.4060  -2.862748
#  2018-07-15  117593.5220  -1163.0840  -0.989071
#  2018-07-16  120425.2475      0.0000   0.000000
#  2018-07-17  120425.2475      0.0000   0.000000
#  2018-07-18  120425.2475      0.0000   0.000000
#  2018-07-19  120425.2475  -1064.3645  -0.883838
#  2018-07-20  120425.2475  -2725.4280  -2.263170
#  2018-07-21  120425.2475  -2725.4280  -2.263170
#  2018-07-22  120425.2475  -2725.4280  -2.263170
#  2018-07-23  120425.2475  -6589.4345  -5.471805
#  2018-07-24  120425.2475  -1044.8630  -0.867644
#  2018-07-25  123536.0440      0.0000   0.000000
#  2018-07-26  123536.0440      0.0000   0.000000
#  2018-07-27  126008.4770      0.0000   0.000000
#  2018-07-28  126008.4770  -1154.0000  -0.915811
#  2018-07-29  126008.4770  -1326.7490  -1.052905
#  2018-07-30  128652.7280      0.0000   0.000000
#  ...                 ...         ...        ...
#  2018-10-23  140694.8850  -8623.8710  -6.129484
#  2018-10-24  140694.8850  -8888.8710  -6.317835
#  2018-10-25  140694.8850  -8601.8710  -6.113848
#  2018-10-26  140694.8850  -8564.8710  -6.087550
#  2018-10-27  140694.8850  -8433.8710  -5.994440
#  2018-10-28  140694.8850  -8527.8710  -6.061252
#  2018-10-29  140694.8850  -6204.4370  -4.409853
#  2018-10-30  140694.8850  -5967.4370  -4.241403
#  2018-10-31  140694.8850  -7220.4370  -5.131983
#  2018-11-01  140694.8850  -6845.4370  -4.865448
#  2018-11-02  140694.8850  -8373.4370  -5.951486
#  2018-11-03  140694.8850  -7806.4370  -5.548487
#  2018-11-04  140694.8850  -9426.4370  -6.699914
#  2018-11-05  140694.8850 -10449.4350  -7.427018
#  2018-11-06  140694.8850 -10449.4350  -7.427018
#  2018-11-07  140694.8850  -9908.9775  -7.042884
#  2018-11-08  140694.8850  -9204.9775  -6.542510
#  2018-11-09  140694.8850  -7566.9775  -5.378289
#  2018-11-10  140694.8850  -7694.9775  -5.469266
#  2018-11-11  140694.8850  -6463.9775  -4.594323
#  2018-11-12  140694.8850  -8006.9775  -5.691022
#  2018-11-13  140694.8850  -7895.9775  -5.612128
#  2018-11-14  140694.8850  -3349.9235  -2.380985
#  2018-11-15  140694.8850  -4926.7610  -3.501734
#  2018-11-16  140694.8850  -6422.5870  -4.564904
#  2018-11-17  140694.8850  -6422.5870  -4.564904
#  2018-11-18  140694.8850  -6295.7585  -4.474760
#  2018-11-19  140694.8850   -994.1740  -0.706617
#  2018-11-20  140694.8850   -994.1740  -0.706617
#  2018-11-21  140694.8850   -994.1740  -0.706617
#
#  [144 rows x 13 columns],
#                      direction exchange exchangeOrderID  fee gatewayName  \
#  dt
#  2018-07-02 06:00:00         多                           0.0
#  2018-07-03 03:18:00         空                           0.0
#  2018-07-04 03:15:00         多                           0.0
#  2018-07-06 12:27:00         空                           0.0
#  2018-07-09 17:00:00         空                           0.0
#  2018-07-10 07:30:00         多                           0.0
#  2018-07-11 08:45:00         多                           0.0
#  2018-07-11 11:46:00         空                           0.0
#  2018-07-14 18:00:00         空                           0.0
#  2018-07-15 00:08:00         多                           0.0
#  2018-07-15 02:00:00         多                           0.0
#  2018-07-15 02:15:00         空                           0.0
#  2018-07-15 02:15:00         空                           0.0
#  2018-07-15 06:00:00         多                           0.0
#  2018-07-15 06:00:00         多                           0.0
#  2018-07-15 06:15:00         空                           0.0
#  2018-07-15 06:15:00         空                           0.0
#  2018-07-15 14:00:00         多                           0.0
#  2018-07-15 14:00:00         多                           0.0
#  2018-07-16 19:25:00         空                           0.0
#  2018-07-19 15:45:00         多                           0.0
#  2018-07-20 00:43:00         空                           0.0
#  2018-07-23 00:00:00         多                           0.0
#  2018-07-23 02:00:00         空                           0.0
#  2018-07-23 02:00:00         空                           0.0
#  2018-07-23 12:07:00         多                           0.0
#  2018-07-24 09:45:00         多                           0.0
#  2018-07-25 08:19:00         空                           0.0
#  2018-07-27 22:15:00         多                           0.0
#  2018-07-29 13:00:00         空                           0.0
#  ...                       ...      ...             ...  ...         ...
#  2018-09-28 17:00:00         空                           0.0
#  2018-10-04 10:00:00         多                           0.0
#  2018-10-04 10:00:00         多                           0.0
#  2018-10-07 17:00:00         空                           0.0
#  2018-10-07 17:00:00         空                           0.0
#  2018-10-08 07:00:00         多                           0.0
#  2018-10-08 07:00:00         多                           0.0
#  2018-10-11 09:09:00         空                           0.0
#  2018-10-14 18:00:00         空                           0.0
#  2018-10-15 13:44:00         多                           0.0
#  2018-10-17 03:00:00         多                           0.0
#  2018-10-19 01:00:00         空                           0.0
#  2018-10-19 01:00:00         空                           0.0
#  2018-10-21 10:00:00         多                           0.0
#  2018-10-21 10:00:00         多                           0.0
#  2018-10-22 08:00:00         空                           0.0
#  2018-10-22 08:00:00         空                           0.0
#  2018-10-29 00:00:00         多                           0.0
#  2018-10-29 00:00:00         多                           0.0
#  2018-10-29 03:00:00         空                           0.0
#  2018-10-29 03:00:00         空                           0.0
#  2018-11-05 02:26:00         多                           0.0
#  2018-11-07 00:00:00         空                           0.0
#  2018-11-14 23:14:00         多                           0.0
#  2018-11-15 14:00:00         多                           0.0
#  2018-11-15 18:16:00         空                           0.0
#  2018-11-16 00:15:00         多                           0.0
#  2018-11-16 17:53:00         空                           0.0
#  2018-11-18 18:00:00         空                           0.0
#  2018-11-19 17:55:00         多                           0.0
#
#                      offset orderID orderTime   price  price_avg rawData  \
#  dt
#  2018-07-02 06:00:00     开仓       1            8.1219        0.0    None
#  2018-07-03 03:18:00     平仓       2            9.1174        0.0    None
#  2018-07-04 03:15:00     开仓       3            8.9085        0.0    None
#  2018-07-06 12:27:00     平仓       4            8.6471        0.0    None
#  2018-07-09 17:00:00     开仓       5            8.5817        0.0    None
#  2018-07-10 07:30:00     平仓       6            7.5190        0.0    None
#  2018-07-11 08:45:00     开仓       7            7.3313        0.0    None
#  2018-07-11 11:46:00     平仓       8            7.1071        0.0    None
#  2018-07-14 18:00:00     开仓       9            6.8428        0.0    None
#  2018-07-15 00:08:00     平仓      10            7.0651        0.0    None
#  2018-07-15 02:00:00     开仓      11            7.0155        0.0    None
#  2018-07-15 02:15:00     平仓      12            6.9821        0.0    None
#  2018-07-15 02:15:00     开仓      13            6.9821        0.0    None
#  2018-07-15 06:00:00     平仓      14            6.9775        0.0    None
#  2018-07-15 06:00:00     开仓      15            6.9775        0.0    None
#  2018-07-15 06:15:00     平仓      16            6.9778        0.0    None
#  2018-07-15 06:15:00     开仓      17            6.9778        0.0    None
#  2018-07-15 14:00:00     平仓      18            6.9901        0.0    None
#  2018-07-15 14:00:00     开仓      19            6.9901        0.0    None
#  2018-07-16 19:25:00     平仓      20            7.8381        0.0    None
#  2018-07-19 15:45:00     开仓      21            8.4729        0.0    None
#  2018-07-20 00:43:00     平仓      22            8.2127        0.0    None
#  2018-07-23 00:00:00     开仓      23            8.1854        0.0    None
#  2018-07-23 02:00:00     平仓      24            8.0598        0.0    None
#  2018-07-23 02:00:00     开仓      25            8.0598        0.0    None
#  2018-07-23 12:07:00     平仓      26            8.2963        0.0    None
#  2018-07-24 09:45:00     开仓      27            7.8857        0.0    None
#  2018-07-25 08:19:00     平仓      28            8.8681        0.0    None
#  2018-07-27 22:15:00     开仓      29            8.1134        0.0    None
#  2018-07-29 13:00:00     平仓      30            8.2749        0.0    None
#  ...                    ...     ...       ...     ...        ...     ...
#  2018-09-28 17:00:00     开仓      95            5.8943        0.0    None
#  2018-10-04 10:00:00     平仓      96            5.6768        0.0    None
#  2018-10-04 10:00:00     开仓      97            5.6768        0.0    None
#  2018-10-07 17:00:00     平仓      98            5.7121        0.0    None
#  2018-10-07 17:00:00     开仓      99            5.7121        0.0    None
#  2018-10-08 07:00:00     平仓     100            5.7266        0.0    None
#  2018-10-08 07:00:00     开仓     101            5.7266        0.0    None
#  2018-10-11 09:09:00     平仓     102            5.5500        0.0    None
#  2018-10-14 18:00:00     开仓     103            5.2762        0.0    None
#  2018-10-15 13:44:00     平仓     104            5.4603        0.0    None
#  2018-10-17 03:00:00     开仓     105            5.5605        0.0    None
#  2018-10-19 01:00:00     平仓     106            5.5307        0.0    None
#  2018-10-19 01:00:00     开仓     107            5.5307        0.0    None
#  2018-10-21 10:00:00     平仓     108            5.5754        0.0    None
#  2018-10-21 10:00:00     开仓     109            5.5754        0.0    None
#  2018-10-22 08:00:00     平仓     110            5.5108        0.0    None
#  2018-10-22 08:00:00     开仓     111            5.5108        0.0    None
#  2018-10-29 00:00:00     平仓     112            5.4284        0.0    None
#  2018-10-29 00:00:00     开仓     113            5.4284        0.0    None
#  2018-10-29 03:00:00     平仓     114            5.4282        0.0    None
#  2018-10-29 03:00:00     开仓     115            5.4282        0.0    None
#  2018-11-05 02:26:00     平仓     116            5.5996        0.0    None
#  2018-11-07 00:00:00     开仓     117            5.7085        0.0    None
#  2018-11-14 23:14:00     平仓     118            4.9892        0.0    None
#  2018-11-15 14:00:00     开仓     119            4.6583        0.0    None
#  2018-11-15 18:16:00     平仓     120            4.5092        0.0    None
#  2018-11-16 00:15:00     开仓     121            4.6531        0.0    None
#  2018-11-16 17:53:00     平仓     122            4.5121        0.0    None
#  2018-11-18 18:00:00     开仓     123            4.6343        0.0    None
#  2018-11-19 17:55:00     平仓     124            4.0831        0.0    None
#
#                      status symbol tradeID           tradeTime  volume  \
#  dt
#  2018-07-02 06:00:00                     1 2018-07-02 06:00:00   10000
#  2018-07-03 03:18:00                     2 2018-07-03 03:18:00   10000
#  2018-07-04 03:15:00                     3 2018-07-04 03:15:00   10000
#  2018-07-06 12:27:00                     4 2018-07-06 12:27:00   10000
#  2018-07-09 17:00:00                     5 2018-07-09 17:00:00   10000
#  2018-07-10 07:30:00                     6 2018-07-10 07:30:00   10000
#  2018-07-11 08:45:00                     7 2018-07-11 08:45:00   10000
#  2018-07-11 11:46:00                     8 2018-07-11 11:46:00   10000
#  2018-07-14 18:00:00                     9 2018-07-14 18:00:00   10000
#  2018-07-15 00:08:00                    10 2018-07-15 00:08:00   10000
#  2018-07-15 02:00:00                    11 2018-07-15 02:00:00   10000
#  2018-07-15 02:15:00                    12 2018-07-15 02:15:00   10000
#  2018-07-15 02:15:00                    13 2018-07-15 02:15:00   10000
#  2018-07-15 06:00:00                    14 2018-07-15 06:00:00   10000
#  2018-07-15 06:00:00                    15 2018-07-15 06:00:00   10000
#  2018-07-15 06:15:00                    16 2018-07-15 06:15:00   10000
#  2018-07-15 06:15:00                    17 2018-07-15 06:15:00   10000
#  2018-07-15 14:00:00                    18 2018-07-15 14:00:00   10000
#  2018-07-15 14:00:00                    19 2018-07-15 14:00:00   10000
#  2018-07-16 19:25:00                    20 2018-07-16 19:25:00   10000
#  2018-07-19 15:45:00                    21 2018-07-19 15:45:00   10000
#  2018-07-20 00:43:00                    22 2018-07-20 00:43:00   10000
#  2018-07-23 00:00:00                    23 2018-07-23 00:00:00   10000
#  2018-07-23 02:00:00                    24 2018-07-23 02:00:00   10000
#  2018-07-23 02:00:00                    25 2018-07-23 02:00:00   10000
#  2018-07-23 12:07:00                    26 2018-07-23 12:07:00   10000
#  2018-07-24 09:45:00                    27 2018-07-24 09:45:00   10000
#  2018-07-25 08:19:00                    28 2018-07-25 08:19:00   10000
#  2018-07-27 22:15:00                    29 2018-07-27 22:15:00   10000
#  2018-07-29 13:00:00                    30 2018-07-29 13:00:00   10000
#  ...                    ...    ...     ...                 ...     ...
#  2018-09-28 17:00:00                    95 2018-09-28 17:00:00   10000
#  2018-10-04 10:00:00                    96 2018-10-04 10:00:00   10000
#  2018-10-04 10:00:00                    97 2018-10-04 10:00:00   10000
#  2018-10-07 17:00:00                    98 2018-10-07 17:00:00   10000
#  2018-10-07 17:00:00                    99 2018-10-07 17:00:00   10000
#  2018-10-08 07:00:00                   100 2018-10-08 07:00:00   10000
#  2018-10-08 07:00:00                   101 2018-10-08 07:00:00   10000
#  2018-10-11 09:09:00                   102 2018-10-11 09:09:00   10000
#  2018-10-14 18:00:00                   103 2018-10-14 18:00:00   10000
#  2018-10-15 13:44:00                   104 2018-10-15 13:44:00   10000
#  2018-10-17 03:00:00                   105 2018-10-17 03:00:00   10000
#  2018-10-19 01:00:00                   106 2018-10-19 01:00:00   10000
#  2018-10-19 01:00:00                   107 2018-10-19 01:00:00   10000
#  2018-10-21 10:00:00                   108 2018-10-21 10:00:00   10000
#  2018-10-21 10:00:00                   109 2018-10-21 10:00:00   10000
#  2018-10-22 08:00:00                   110 2018-10-22 08:00:00   10000
#  2018-10-22 08:00:00                   111 2018-10-22 08:00:00   10000
#  2018-10-29 00:00:00                   112 2018-10-29 00:00:00   10000
#  2018-10-29 00:00:00                   113 2018-10-29 00:00:00   10000
#  2018-10-29 03:00:00                   114 2018-10-29 03:00:00   10000
#  2018-10-29 03:00:00                   115 2018-10-29 03:00:00   10000
#  2018-11-05 02:26:00                   116 2018-11-05 02:26:00   10000
#  2018-11-07 00:00:00                   117 2018-11-07 00:00:00   10000
#  2018-11-14 23:14:00                   118 2018-11-14 23:14:00   10000
#  2018-11-15 14:00:00                   119 2018-11-15 14:00:00   10000
#  2018-11-15 18:16:00                   120 2018-11-15 18:16:00   10000
#  2018-11-16 00:15:00                   121 2018-11-16 00:15:00   10000
#  2018-11-16 17:53:00                   122 2018-11-16 17:53:00   10000
#  2018-11-18 18:00:00                   123 2018-11-18 18:00:00   10000
#  2018-11-19 17:55:00                   124 2018-11-19 17:55:00   10000
#
#                      vtOrderID         vtSymbol vtTradeID
#  dt
#  2018-07-02 06:00:00         1  EOSUSDT:binance         1
#  2018-07-03 03:18:00         2  EOSUSDT:binance         2
#  2018-07-04 03:15:00         3  EOSUSDT:binance         3
#  2018-07-06 12:27:00         4  EOSUSDT:binance         4
#  2018-07-09 17:00:00         5  EOSUSDT:binance         5
#  2018-07-10 07:30:00         6  EOSUSDT:binance         6
#  2018-07-11 08:45:00         7  EOSUSDT:binance         7
#  2018-07-11 11:46:00         8  EOSUSDT:binance         8
#  2018-07-14 18:00:00         9  EOSUSDT:binance         9
#  2018-07-15 00:08:00        10  EOSUSDT:binance        10
#  2018-07-15 02:00:00        11  EOSUSDT:binance        11
#  2018-07-15 02:15:00        12  EOSUSDT:binance        12
#  2018-07-15 02:15:00        13  EOSUSDT:binance        13
#  2018-07-15 06:00:00        14  EOSUSDT:binance        14
#  2018-07-15 06:00:00        15  EOSUSDT:binance        15
#  2018-07-15 06:15:00        16  EOSUSDT:binance        16
#  2018-07-15 06:15:00        17  EOSUSDT:binance        17
#  2018-07-15 14:00:00        18  EOSUSDT:binance        18
#  2018-07-15 14:00:00        19  EOSUSDT:binance        19
#  2018-07-16 19:25:00        20  EOSUSDT:binance        20
#  2018-07-19 15:45:00        21  EOSUSDT:binance        21
#  2018-07-20 00:43:00        22  EOSUSDT:binance        22
#  2018-07-23 00:00:00        23  EOSUSDT:binance        23
#  2018-07-23 02:00:00        24  EOSUSDT:binance        24
#  2018-07-23 02:00:00        25  EOSUSDT:binance        25
#  2018-07-23 12:07:00        26  EOSUSDT:binance        26
#  2018-07-24 09:45:00        27  EOSUSDT:binance        27
#  2018-07-25 08:19:00        28  EOSUSDT:binance        28
#  2018-07-27 22:15:00        29  EOSUSDT:binance        29
#  2018-07-29 13:00:00        30  EOSUSDT:binance        30
#  ...                       ...              ...       ...
#  2018-09-28 17:00:00        95  EOSUSDT:binance        95
#  2018-10-04 10:00:00        96  EOSUSDT:binance        96
#  2018-10-04 10:00:00        97  EOSUSDT:binance        97
#  2018-10-07 17:00:00        98  EOSUSDT:binance        98
#  2018-10-07 17:00:00        99  EOSUSDT:binance        99
#  2018-10-08 07:00:00       100  EOSUSDT:binance       100
#  2018-10-08 07:00:00       101  EOSUSDT:binance       101
#  2018-10-11 09:09:00       102  EOSUSDT:binance       102
#  2018-10-14 18:00:00       103  EOSUSDT:binance       103
#  2018-10-15 13:44:00       104  EOSUSDT:binance       104
#  2018-10-17 03:00:00       105  EOSUSDT:binance       105
#  2018-10-19 01:00:00       106  EOSUSDT:binance       106
#  2018-10-19 01:00:00       107  EOSUSDT:binance       107
#  2018-10-21 10:00:00       108  EOSUSDT:binance       108
#  2018-10-21 10:00:00       109  EOSUSDT:binance       109
#  2018-10-22 08:00:00       110  EOSUSDT:binance       110
#  2018-10-22 08:00:00       111  EOSUSDT:binance       111
#  2018-10-29 00:00:00       112  EOSUSDT:binance       112
#  2018-10-29 00:00:00       113  EOSUSDT:binance       113
#  2018-10-29 03:00:00       114  EOSUSDT:binance       114
#  2018-10-29 03:00:00       115  EOSUSDT:binance       115
#  2018-11-05 02:26:00       116  EOSUSDT:binance       116
#  2018-11-07 00:00:00       117  EOSUSDT:binance       117
#  2018-11-14 23:14:00       118  EOSUSDT:binance       118
#  2018-11-15 14:00:00       119  EOSUSDT:binance       119
#  2018-11-15 18:16:00       120  EOSUSDT:binance       120
#  2018-11-16 00:15:00       121  EOSUSDT:binance       121
#  2018-11-16 17:53:00       122  EOSUSDT:binance       122
#  2018-11-18 18:00:00       123  EOSUSDT:binance       123
#  2018-11-19 17:55:00       124  EOSUSDT:binance       124
#
#  [124 rows x 19 columns])
